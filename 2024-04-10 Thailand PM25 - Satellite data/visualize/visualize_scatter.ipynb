# %% [markdown]
# ## Import Lib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from zkyhaxpy import io_tools, gis_tools, pd_tools
import rasterio
import os
import shutil
import numpy as np
from tqdm.notebook import tqdm
import aqi
import numpy as np
from scipy import stats
import plotly.express as px

# %% [markdown]
# ## Define constants

# %%
aqi_color_codes = {
        -9:"Grey",
        0: "Green",
        1: "Yellow",
        2: "Orange",
        3: "Red",
        4: "Purple",
        5: "Maroon"
    }

# %% [markdown]
# ## Define functions

# %% [markdown]
# ### pm25_to_aqi_level

# %%
def pm25_to_aqi_level(pm25_concentration: float) -> int:
    """
    Converts PM2.5 concentration to AQI class (as integer).

    Args:
        pm25_concentration (float): PM2.5 concentration in µg/m³.

    Returns:
        int: AQI level (0 to 5) based on EPA guidelines.
    """
    aqi_value = aqi.to_aqi([(aqi.POLLUTANT_PM25, str(pm25_concentration))])
    if aqi_value <= 50:
        return 0  # Good
    elif 50 < aqi_value <= 100:
        return 1  # Moderate
    elif 100 < aqi_value <= 150:
        return 2  # Unhealthy for Sensitive Groups
    elif 150 < aqi_value <= 200:
        return 3  # Unhealthy
    elif 200 < aqi_value <= 300:
        return 4  # Very Unhealthy
    else:
        return 5  # Hazardous

# %% [markdown]
# ### aqi_level_to_color

# %%
def aqi_level_to_color(aqi_class: int) -> str:
    """
    Converts AQI level (as integer) to color code.

    Args:
        aqi_class (int): AQI level (0 to 5).

    Returns:
        str: Color code corresponding to the AQI level.
    """
    color_codes = {
        0: "Green",
        1: "Yellow",
        2: "Orange",
        3: "Red",
        4: "Purple",
        5: "Maroon"
    }
    return color_codes.get(aqi_class, "Unknown")

# %% [markdown]
# ## Load data for training model

# %%
df_chiangmai_grid = pd.read_parquet(r'../data/df_chiangmai_grid.parquet')

lat_min = df_chiangmai_grid.lat.min()
lat_max = df_chiangmai_grid.lat.max()
lon_min = df_chiangmai_grid.lon.min()
lon_max = df_chiangmai_grid.lon.max()

# %%
df_extracted_aod055 = pd.read_csv(r'../data/df_extracted_openaq_aod055_v2.csv')
del(df_extracted_aod055['row'])
del(df_extracted_aod055['col'])
del(df_extracted_aod055['tile_id'])

df_extracted_dem = pd.read_csv(r'../data/df_extracted_openaq_dem_v2.csv')
del(df_extracted_dem['row'])
del(df_extracted_dem['col'])


path_df_openaq = r'../data/gdf_openaq_chiangmai_by_location.parquet'
if os.path.exists(path_df_openaq):
    df_openaq = pd.read_parquet(path_df_openaq)
    print(f'{path_df_openaq} has been loaded')
else:
    gdf_openaq = gpd.read_file('../data/gdf_openaq_chiangmai_by_location.gpkg')
    print('gdf_openaq has been loaded.')
    if gdf_openaq.index.name is None:
        gdf_openaq = gdf_openaq.set_index('measurement_id')
    
    df_openaq = gdf_openaq.drop(columns=['geometry']).copy()
    df_openaq.to_parquet(path_df_openaq)
    print(f'{path_df_openaq} has been saved')
# Out:
# ../data/gdf_openaq_chiangmai_by_location.parquet has been loaded

# %%
df_openaq = df_openaq[df_openaq['value'] != -999].copy()
df_openaq
# Out:
#                 locationId                      location parameter      value  \
# measurement_id
# 0                  1235996                Vieng Nua, Pai      pm25   2.191964
# 1                  1235996                Vieng Nua, Pai      pm25   2.313988
# 2                  1235996                Vieng Nua, Pai      pm25   2.580357
# 3                  1235996                Vieng Nua, Pai      pm25   3.220238
# 4                  1235996                Vieng Nua, Pai      pm25   3.644345
# ...                    ...                           ...       ...        ...
# 253632              523937  Tha Kham Municipality Office      pm25   9.600000
# 253633              523937  Tha Kham Municipality Office      pm25   9.700000
# 253634              523937  Tha Kham Municipality Office      pm25   9.800000
# 253635              523937  Tha Kham Municipality Office      pm25  10.200000
# 253636              523937  Tha Kham Municipality Office      pm25  10.400000
#
#                       date   unit country  city  isMobile isAnalysis  \
# measurement_id
# 0               2023-10-31  µg/m³      TH  None     False       None
# 1               2023-10-30  µg/m³      TH  None     False       None
# 2               2023-10-30  µg/m³      TH  None     False       None
# 3               2023-10-30  µg/m³      TH  None     False       None
# 4               2023-10-30  µg/m³      TH  None     False       None
# ...                    ...    ...     ...   ...       ...        ...
# 253632          2023-06-01  µg/m³      TH  None     False       None
# 253633          2023-06-01  µg/m³      TH  None     False       None
# 253634          2023-06-01  µg/m³      TH  None     False       None
# 253635          2023-06-01  µg/m³      TH  None     False       None
# 253636          2023-06-01  µg/m³      TH  None     False       None
#
#                                    entity       sensorType          datetime  \
# measurement_id
# 0               Governmental Organization  low-cost sensor  2023-10-31T00:00
# 1               Governmental Organization  low-cost sensor  2023-10-30T23:00
# 2               Governmental Organization  low-cost sensor  2023-10-30T22:00
# 3               Governmental Organization  low-cost sensor  2023-10-30T21:00
# 4               Governmental Organization  low-cost sensor  2023-10-30T20:00
# ...                                   ...              ...               ...
# 253632          Governmental Organization  reference grade  2023-06-01T06:00
# 253633          Governmental Organization  reference grade  2023-06-01T05:00
# 253634          Governmental Organization  reference grade  2023-06-01T04:00
# 253635          Governmental Organization  reference grade  2023-06-01T02:00
# 253636          Governmental Organization  reference grade  2023-06-01T01:00
#
#                 year month year_month   time        lat        lon
# measurement_id
# 0               2023    0-   2023-10-  00:00  19.374620  98.445611
# 1               2023    0-   2023-10-  23:00  19.374620  98.445611
# 2               2023    0-   2023-10-  22:00  19.374620  98.445611
# 3               2023    0-   2023-10-  21:00  19.374620  98.445611
# 4               2023    0-   2023-10-  20:00  19.374620  98.445611
# ...              ...   ...        ...    ...        ...        ...
# 253632          2023    6-   2023-06-  06:00  18.202222  98.597222
# 253633          2023    6-   2023-06-  05:00  18.202222  98.597222
# 253634          2023    6-   2023-06-  04:00  18.202222  98.597222
# 253635          2023    6-   2023-06-  02:00  18.202222  98.597222
# 253636          2023    6-   2023-06-  01:00  18.202222  98.597222
#
# [253637 rows x 19 columns]

# %%
df_openaq['locationId'].nunique()
# Out:
# 73

# %%
df_extracted_aod055 = df_extracted_aod055[df_extracted_aod055['aod_055'] >= 0].copy()
df_extracted_aod055 = df_extracted_aod055.set_index('measurement_id')
df_extracted_aod055
# Out:
#                 aod_055               aod_datetime
# measurement_id
# 157249            632.0  2022-04-19 07:05:00+00:00
# 157250            632.0  2022-04-19 07:05:00+00:00
# 205094            357.0  2022-04-19 07:05:00+00:00
# 205095            357.0  2022-04-19 07:05:00+00:00
# 118040            177.0  2023-01-21 07:45:00+00:00
# ...                 ...                        ...
# 235082            248.0  2024-03-09 07:35:00+00:00
# 245072            534.0  2024-03-09 07:35:00+00:00
# 245073            534.0  2024-03-09 07:35:00+00:00
# 250183            290.0  2024-03-09 07:35:00+00:00
# 250184            290.0  2024-03-09 07:35:00+00:00
#
# [17248 rows x 2 columns]

# %%
df_extracted_dem = df_extracted_dem.copy()
df_extracted_dem = df_extracted_dem.set_index('measurement_id')
df_extracted_dem
# Out:
#                   dem
# measurement_id
# 0               524.0
# 1               524.0
# 2               524.0
# 3               524.0
# 4               524.0
# ...               ...
# 253632          291.0
# 253633          291.0
# 253634          291.0
# 253635          291.0
# 253636          291.0
#
# [253637 rows x 1 columns]

# %%
df_joined = df_openaq.merge(df_extracted_aod055, how='inner', left_index=True, right_index=True).copy()
df_joined = df_joined.merge(df_extracted_dem, how='inner', left_index=True, right_index=True).copy()
df_joined = df_joined.rename(columns={'value':'pm25'})


df_joined['year_month'] = df_joined['year_month'].str.slice(0, 7)
df_joined['month'] = df_joined['year_month'].str.slice(5, 7)
df_joined
# Out:
#                 locationId                      location parameter       pm25  \
# measurement_id
# 108                1235996                Vieng Nua, Pai      pm25  21.903274
# 109                1235996                Vieng Nua, Pai      pm25  20.860119
# 127                1235996                Vieng Nua, Pai      pm25  10.125000
# 128                1235996                Vieng Nua, Pai      pm25  12.901786
# 131                1235996                Vieng Nua, Pai      pm25  14.886905
# ...                    ...                           ...       ...        ...
# 253493              523937  Tha Kham Municipality Office      pm25  34.000000
# 253516              523937  Tha Kham Municipality Office      pm25  36.000000
# 253517              523937  Tha Kham Municipality Office      pm25  36.000000
# 253584              523937  Tha Kham Municipality Office      pm25  25.000000
# 253585              523937  Tha Kham Municipality Office      pm25  24.000000
#
#                       date   unit country  city  isMobile isAnalysis  ...  \
# measurement_id                                                        ...
# 108             2023-10-26  µg/m³      TH  None     False       None  ...
# 109             2023-10-26  µg/m³      TH  None     False       None  ...
# 127             2023-10-25  µg/m³      TH  None     False       None  ...
# 128             2023-10-25  µg/m³      TH  None     False       None  ...
# 131             2023-10-25  µg/m³      TH  None     False       None  ...
# ...                    ...    ...     ...   ...       ...        ...  ...
# 253493          2023-05-06  µg/m³      TH  None     False       None  ...
# 253516          2023-05-05  µg/m³      TH  None     False       None  ...
# 253517          2023-05-05  µg/m³      TH  None     False       None  ...
# 253584          2023-05-02  µg/m³      TH  None     False       None  ...
# 253585          2023-05-02  µg/m³      TH  None     False       None  ...
#
#                         datetime  year month year_month   time        lat  \
# measurement_id
# 108             2023-10-26T05:00  2023    10    2023-10  05:00  19.374620
# 109             2023-10-26T04:00  2023    10    2023-10  04:00  19.374620
# 127             2023-10-25T08:00  2023    10    2023-10  08:00  19.374620
# 128             2023-10-25T07:00  2023    10    2023-10  07:00  19.374620
# 131             2023-10-25T04:00  2023    10    2023-10  04:00  19.374620
# ...                          ...   ...   ...        ...    ...        ...
# 253493          2023-05-06T04:00  2023    05    2023-05  04:00  18.202222
# 253516          2023-05-05T04:00  2023    05    2023-05  04:00  18.202222
# 253517          2023-05-05T03:00  2023    05    2023-05  03:00  18.202222
# 253584          2023-05-02T04:00  2023    05    2023-05  04:00  18.202222
# 253585          2023-05-02T03:00  2023    05    2023-05  03:00  18.202222
#
#                       lon  aod_055               aod_datetime    dem
# measurement_id
# 108             98.445611    191.0  2023-10-26 04:15:00+00:00  524.0
# 109             98.445611    191.0  2023-10-26 04:15:00+00:00  524.0
# 127             98.445611    211.0  2023-10-25 07:05:00+00:00  524.0
# 128             98.445611    211.0  2023-10-25 07:05:00+00:00  524.0
# 131             98.445611    195.0  2023-10-25 03:30:00+00:00  524.0
# ...                   ...      ...                        ...    ...
# 253493          98.597222    348.0  2023-05-06 04:20:00+00:00  291.0
# 253516          98.597222    318.0  2023-05-05 03:40:00+00:00  291.0
# 253517          98.597222    318.0  2023-05-05 03:40:00+00:00  291.0
# 253584          98.597222    356.0  2023-05-02 03:15:00+00:00  291.0
# 253585          98.597222    356.0  2023-05-02 03:15:00+00:00  291.0
#
# [17248 rows x 22 columns]

# %%
df_pm25_ori = df_joined[(df_joined['lat'].between(lat_min, lat_max)) & (df_joined['lon'].between(lon_min, lon_max))]
df_pm25_ori = df_pm25_ori.reindex(columns=['pm25', 'aod_055', 'dem', 'sensorType', 'locationId']).copy()
df_pm25_ori
# Out:
#                      pm25  aod_055    dem       sensorType  locationId
# measurement_id
# 108             21.903274    191.0  524.0  low-cost sensor     1235996
# 109             20.860119    191.0  524.0  low-cost sensor     1235996
# 127             10.125000    211.0  524.0  low-cost sensor     1235996
# 128             12.901786    211.0  524.0  low-cost sensor     1235996
# 131             14.886905    195.0  524.0  low-cost sensor     1235996
# ...                   ...      ...    ...              ...         ...
# 253493          34.000000    348.0  291.0  reference grade      523937
# 253516          36.000000    318.0  291.0  reference grade      523937
# 253517          36.000000    318.0  291.0  reference grade      523937
# 253584          25.000000    356.0  291.0  reference grade      523937
# 253585          24.000000    356.0  291.0  reference grade      523937
#
# [16082 rows x 5 columns]

# %%
#Filter only Open AQ measurement within Chiangmai boundary
gdf_province = gpd.read_file(r'..\data\thailandWithName.json')
gdf_chiangmai = gdf_province[gdf_province['name'] == 'Chiang Mai']
df_openaq_location = df_openaq.copy()
df_openaq_location = df_openaq_location.reindex(columns=['locationId', 'location', 'sensorType', 'entity', 'lat', 'lon']).drop_duplicates()
df_openaq_location['geometry'] = 'POINT (' + df_openaq_location['lon'].astype(str) + ' ' + df_openaq_location['lat'].astype(str) + ')'
gdf_openaq_location = gis_tools.df_to_gdf(df_openaq_location, 'geometry')
gdf_openaq_location_chiangmai = gdf_openaq_location[gdf_openaq_location.geometry.within(gdf_chiangmai.geometry.iloc[0])]
len(gdf_openaq_location_chiangmai)

list_location_id = gdf_openaq_location_chiangmai['locationId'].to_list()
list_location_id
# Out:
# [1235999,
#  1236014,
#  1236022,
#  1236024,
#  1236040,
#  1236050,
#  1236066,
#  1405439,
#  1641552,
#  1641558,
#  1646752,
#  1753562,
#  1753563,
#  1753564,
#  1861095,
#  1861445,
#  1864570,
#  1935353,
#  2041043,
#  2169936,
#  2174592,
#  225579,
#  225583,
#  225669,
#  225693,
#  2379288,
#  2429011,
#  2432814,
#  2461311,
#  2575375,
#  270292,
#  2807918,
#  387660,
#  388656,
#  523937]

# %%
df_pm25 = df_pm25_ori.copy()
df_pm25 = df_pm25[df_pm25['locationId'].isin(list_location_id)].copy()
res = stats.pearsonr(df_pm25['aod_055'], df_pm25['pm25'])
res
# Out:
# PearsonRResult(statistic=0.7876213000276187, pvalue=0.0)

# %%
df_pm25['pm25'] = df_pm25['pm25'].round(1)

# %%
fig = px.scatter(df_pm25, x='aod_055', y='pm25', color='sensorType')
fig.update_layout(
    yaxis_title='PM2.5 (µg/m3)',
    xaxis_title='AOD (MODIS)',
    title='Scatter Plot - PM2.5 (OpenAQ) and AOD (MODIS) in Chiangmai (2021 to Present)')


fig.write_html(f'fig-scatter.html', div_id='scatter', full_html=False, include_plotlyjs=False)
fig

# %% [markdown]
# ## For LazyPlotly (PIER-X)

# %%
df_pm25
# Out:
#                 pm25  aod_055    dem       sensorType  locationId
# measurement_id
# 5888            12.1    110.0  338.0  low-cost sensor     1235999
# 5889            14.2    110.0  338.0  low-cost sensor     1235999
# 5934            15.1    247.0  338.0  low-cost sensor     1235999
# 5935            15.3    247.0  338.0  low-cost sensor     1235999
# 5957            18.0    275.0  338.0  low-cost sensor     1235999
# ...              ...      ...    ...              ...         ...
# 253493          34.0    348.0  291.0  reference grade      523937
# 253516          36.0    318.0  291.0  reference grade      523937
# 253517          36.0    318.0  291.0  reference grade      523937
# 253584          25.0    356.0  291.0  reference grade      523937
# 253585          24.0    356.0  291.0  reference grade      523937
#
# [9488 rows x 5 columns]

# %%
df_pm25_lazyplotly = df_pm25.copy().drop(columns=['locationId', 'dem'])
df_pm25_lazyplotly.columns = ['y_pm25', 'x_aod', 'sensor_type']
df_pm25_lazyplotly.to_csv('df_scatter_full.csv', index=False)
df_pm25_lazyplotly.sample(1000, random_state=88).to_csv('df_scatter_sample1000.csv', index=False)

# %%
df_pm25_lazyplotly['aod_055'] = df_pm25_lazyplotly['aod_055'].astype(int)
df_pm25_lazyplotly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_pm25_lazyplotly['aod_055'] = df_pm25_lazyplotly['aod_055'].astype(int)
#       2 df_pm25_lazyplotly
#
# NameError: name 'df_pm25_lazyplotly' is not defined

# %%
df_pm25_lazyplotly_refgrade = df_pm25_lazyplotly[df_pm25_lazyplotly['sensorType']=='reference grade'].copy().drop(columns=['locationId', 'dem'])
df_pm25_lazyplotly_refgrade
# Out:
#                 pm25  aod_055       sensorType
# measurement_id
# 49636           13.4       50  reference grade
# 49637           14.7       50  reference grade
# 49652           33.0      212  reference grade
# 49653           34.8      212  reference grade
# 49679           39.1       89  reference grade
# ...              ...      ...              ...
# 253493          34.0      348  reference grade
# 253516          36.0      318  reference grade
# 253517          36.0      318  reference grade
# 253584          25.0      356  reference grade
# 253585          24.0      356  reference grade
#
# [4372 rows x 3 columns]

# %%
df_pm25_lazyplotly_lowcost = df_pm25_lazyplotly[df_pm25_lazyplotly['sensorType']=='low-cost sensor'].copy().drop(columns=['locationId', 'dem'])
df_pm25_lazyplotly_lowcost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_pm25_lazyplotly_lowcost = df_pm25_lazyplotly[df_pm25_lazyplotly['sensorType']=='low-cost sensor'].copy().drop(columns=['locationId', 'dem'])
#       2 df_pm25_lazyplotly_lowcost
#
# NameError: name 'df_pm25_lazyplotly' is not defined

# %%
df_pm25_lazyplotly_lowcost

# %%
df_pm25_lazyplotly_tmp = df_pm25_lazyplotly_lowcost.copy().sample(1000, random_state=88)
df_pm25_lazyplotly_tmp.columns = ['y', 'x', '_']
str_x = 'x: ['
str_y = 'y: ['
for _, s_row in df_pm25_lazyplotly_tmp.iterrows():
    str_x = str_x + f"{s_row.x},"
    str_y = str_y + f"{s_row.y},"

str_x = str_x + '],'    
str_y = str_y + '],'

print(str_x)
print(str_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_pm25_lazyplotly_tmp = df_pm25_lazyplotly_lowcost.copy().sample(1000, random_state=88)
#       2 df_pm25_lazyplotly_tmp.columns = ['y', 'x', '_']
#       3 str_x = 'x: ['
#
# NameError: name 'df_pm25_lazyplotly_lowcost' is not defined

# %%
df_pm25_lazyplotly_tmp = df_pm25_lazyplotly_refgrade.copy().sample(1000, random_state=88)
df_pm25_lazyplotly_tmp.columns = ['y', 'x', '_']
str_x = 'x: ['
str_y = 'y: ['
for _, s_row in df_pm25_lazyplotly_tmp.iterrows():
    str_x = str_x + f"{s_row.x},"
    str_y = str_y + f"{s_row.y},"

str_x = str_x + '],'    
str_y = str_y + '],'

print(str_x)
print(str_y)
# Out:
# x: [151,158,196,304,87,185,414,501,1190,1365,1116,1082,419,892,117,56,98,208,228,130,937,502,43,113,100,11,75,188,944,115,306,195,11,351,421,1251,713,1410,851,129,172,203,154,187,477,186,43,193,838,212,1545,789,465,116,225,137,282,265,637,25,726,211,169,1137,219,38,511,123,256,671,419,969,75,177,119,164,85,443,219,317,142,555,477,190,204,778,374,461,79,148,190,561,130,1138,118,89,221,291,30,798,1325,957,306,104,287,189,1020,449,483,367,1121,0,190,204,582,337,73,177,172,875,184,939,242,187,962,218,207,360,63,467,61,466,284,109,391,105,272,105,316,366,202,186,130,187,56,1136,351,823,127,193,227,166,98,222,268,242,680,551,451,426,41,23,36,303,384,95,114,140,187,196,298,315,25,235,1077,177,62,100,116,23,377,718,327,183,969,749,112,196,76,185,651,512,138,190,49,37,233,114,87,399,182,378,870,733,466,109,752,45,309,345,455,608,1410,537,187,117,91,259,664,80,266,85,934,223,489,733,813,64,100,354,818,506,167,1042,233,220,212,1340,51,268,311,3,219,125,208,50,121,345,461,1018,72,114,59,391,162,184,122,1564,1545,1349,334,4,426,56,222,68,344,1085,314,241,253,88,69,379,312,282,196,994,679,133,109,233,429,589,1158,79,48,178,8,73,198,111,8,13,895,179,96,789,379,1267,91,740,427,506,558,52,1287,85,219,203,1374,207,332,157,291,763,205,670,88,239,229,139,520,132,378,719,476,366,1371,160,513,426,53,420,0,173,150,309,233,1676,446,186,109,873,1345,489,260,76,40,152,761,62,182,214,1207,316,127,218,409,401,103,15,322,220,30,1251,130,148,223,1231,603,1018,88,176,133,740,213,224,450,354,29,100,542,375,1559,651,1190,60,765,256,325,239,98,857,478,851,94,435,609,378,49,130,185,1286,235,630,157,423,151,454,286,110,205,470,83,416,100,14,161,1365,137,768,229,58,32,161,213,1320,12,4,210,582,501,345,334,61,47,211,1042,68,132,810,1353,93,797,761,383,179,632,123,464,110,116,166,3,316,160,280,236,240,158,672,274,628,296,370,205,599,89,142,177,205,224,48,62,463,201,1116,349,583,46,846,943,184,114,349,373,109,162,55,340,71,128,120,116,108,75,160,195,172,130,111,964,44,653,148,522,76,130,100,563,43,156,377,277,552,336,67,83,345,211,103,732,93,801,751,453,408,162,71,199,182,168,50,1125,488,293,110,380,187,240,205,794,1465,316,56,1081,100,36,469,399,188,13,2,184,956,567,421,284,123,794,35,558,126,542,846,98,609,11,1013,580,287,176,47,801,378,1955,372,91,120,159,1320,53,190,126,208,126,1002,626,464,370,139,159,27,1301,109,438,201,312,83,27,56,160,152,256,362,367,611,507,917,216,223,329,173,355,132,518,71,536,340,35,718,1085,740,985,293,56,480,190,56,275,1101,444,309,702,93,592,895,1301,15,553,721,406,135,198,866,468,472,56,965,294,150,1174,157,272,1179,158,761,308,118,137,65,324,764,107,278,391,130,107,139,344,718,226,568,314,365,67,80,25,30,172,112,930,489,288,194,2094,370,44,522,2,363,1107,33,228,190,426,11,203,197,330,17,848,662,352,244,400,152,264,596,240,280,167,129,379,1274,267,29,184,328,76,979,166,211,588,353,1077,1154,261,101,153,71,1170,12,601,542,490,130,349,336,332,220,218,1011,1006,282,222,102,242,31,233,224,1330,1024,464,371,278,577,1202,234,220,311,714,241,37,74,324,324,160,378,171,324,227,72,200,207,1163,422,30,427,143,168,91,311,334,254,319,438,353,209,37,450,301,446,158,168,1955,126,1663,513,102,92,401,203,988,491,88,118,461,177,6,268,152,62,580,176,150,104,229,1608,1517,175,126,62,167,172,491,108,256,24,384,291,310,263,939,445,913,213,227,408,240,105,132,268,400,1416,241,378,942,220,147,286,67,32,183,282,537,91,421,214,106,751,66,268,152,18,538,330,52,274,262,162,80,59,389,27,1137,203,236,1208,89,141,126,114,300,183,264,898,940,354,190,153,578,268,256,120,1989,539,285,168,679,980,515,167,263,163,538,414,281,209,440,293,130,158,507,348,846,136,109,1834,669,922,77,1202,119,742,295,151,363,199,42,163,423,112,732,217,55,281,227,131,304,526,501,328,277,913,185,157,9,153,258,1314,82,23,243,340,177,354,1238,108,304,8,239,197,718,576,144,110,272,109,179,228,622,215,957,942,191,341,52,1307,1036,557,251,438,869,1196,952,164,985,311,750,66,53,245,14,15,1192,246,2,127,],
# y: [25.0,17.0,39.0,20.0,12.6,23.8,44.9,46.0,164.0,148.9,143.6,116.0,46.0,52.2,13.0,7.0,31.0,40.0,21.0,15.0,63.0,41.4,16.0,32.6,29.0,34.6,20.0,26.0,145.3,13.0,26.9,8.0,34.0,28.0,71.0,123.6,41.8,134.2,40.0,47.0,36.0,22.2,29.0,68.0,26.0,12.0,12.0,17.0,55.5,33.0,136.0,61.0,24.0,23.0,28.2,12.9,13.0,19.0,22.0,32.0,62.4,10.5,21.1,175.0,33.0,12.7,47.0,34.0,21.8,89.1,46.0,125.0,43.0,17.9,22.0,20.0,24.3,45.0,21.0,27.0,26.0,86.0,48.0,13.0,32.0,55.0,37.1,76.0,22.0,22.0,24.0,50.0,31.4,135.1,15.7,17.0,14.0,19.0,12.0,30.2,149.5,131.9,32.0,20.9,66.0,14.2,113.6,195.0,53.0,31.5,100.9,17.0,15.0,51.5,47.1,17.0,12.0,56.0,16.0,94.2,38.0,61.1,26.0,18.0,109.9,27.0,22.4,44.1,26.0,30.6,20.9,45.0,31.0,14.0,31.0,27.0,46.3,16.7,29.0,31.0,11.0,31.0,24.3,29.0,36.0,133.3,90.0,107.0,7.0,17.0,33.0,18.4,32.4,30.0,43.0,45.2,56.1,88.4,42.0,56.0,10.0,28.9,14.9,36.7,50.0,15.9,21.9,25.4,28.9,14.1,34.0,9.9,18.0,42.5,115.3,11.0,24.0,23.0,20.9,28.9,37.0,58.9,38.0,40.0,125.1,53.3,25.3,39.0,21.0,22.2,74.0,53.4,24.0,28.9,29.0,24.0,42.0,14.4,42.0,56.0,40.2,33.0,47.0,68.0,35.0,12.5,114.1,28.3,42.0,37.0,58.0,54.0,135.9,40.0,25.0,12.0,26.2,78.0,117.0,19.8,43.0,28.0,111.0,13.2,23.0,68.4,158.0,16.0,21.0,21.0,148.0,142.0,26.0,152.3,26.0,18.0,30.0,331.0,31.0,35.0,18.0,16.7,33.0,37.3,16.0,13.0,26.0,36.7,30.7,84.6,22.0,19.6,32.8,15.0,33.0,25.0,21.0,119.1,136.0,229.0,40.0,16.8,53.0,15.0,41.7,13.5,22.0,160.0,61.7,45.3,15.0,18.0,32.0,37.2,32.9,13.0,27.0,57.4,84.0,25.0,22.4,50.6,60.0,47.6,119.0,21.0,19.1,16.0,16.3,37.4,9.9,34.0,16.3,21.0,80.8,19.1,18.0,106.3,29.0,135.0,27.0,166.0,28.0,145.0,49.5,29.0,135.5,17.0,13.0,24.0,248.0,23.0,66.0,36.4,47.5,76.2,34.9,84.0,21.2,32.0,48.0,24.0,58.0,23.0,166.2,11.0,13.0,90.5,118.2,27.0,93.2,48.0,14.0,20.0,18.3,19.0,22.0,38.0,20.0,297.0,91.3,24.8,21.5,105.0,184.0,82.6,30.0,20.0,18.0,23.0,64.0,14.0,22.0,17.0,90.8,19.0,23.0,44.0,43.0,47.0,31.0,34.7,25.0,27.0,22.5,123.6,18.7,18.0,10.0,148.0,53.0,83.6,32.4,21.8,39.0,62.0,13.0,33.8,38.0,51.0,14.6,14.0,16.0,29.8,151.8,74.0,163.0,20.2,21.0,21.0,14.9,26.0,25.3,94.0,45.5,40.0,35.8,26.0,40.0,29.0,29.0,8.8,13.0,121.0,12.0,164.0,22.0,37.6,15.0,73.9,27.4,23.0,41.3,35.9,29.0,35.0,16.0,16.7,38.3,151.2,19.8,78.0,48.0,74.0,35.0,25.7,41.4,341.0,17.0,16.8,27.0,45.9,48.0,36.0,30.0,8.0,33.8,46.0,249.0,13.0,19.0,60.8,134.9,24.0,79.0,102.2,34.0,38.0,101.0,34.0,32.0,28.5,37.5,6.0,16.5,32.0,14.0,28.0,34.2,19.0,34.0,99.0,23.1,60.0,26.0,11.0,26.0,47.0,37.0,16.3,24.0,45.0,13.0,12.0,25.0,36.0,28.0,143.9,41.0,67.5,36.0,111.0,61.2,29.0,16.1,36.5,58.0,13.0,21.6,29.0,47.0,28.0,24.0,27.0,35.9,27.0,21.0,50.3,27.0,37.0,35.0,11.0,37.0,12.1,33.0,18.0,40.0,46.0,35.0,39.0,58.0,16.2,24.1,42.7,18.0,113.9,56.0,17.6,41.0,36.0,14.0,27.8,63.2,21.0,75.6,76.9,49.5,32.0,15.4,27.0,20.0,49.0,42.2,15.8,110.4,50.0,36.0,25.0,20.0,25.0,86.4,36.0,47.0,219.0,32.0,14.0,89.0,21.7,30.0,37.0,36.7,26.0,20.8,15.8,22.0,49.3,47.0,10.0,23.0,34.0,158.0,18.0,50.0,21.0,38.0,158.0,23.0,83.0,12.3,135.0,30.0,7.0,40.0,32.0,73.9,22.0,56.0,41.0,25.8,11.0,32.0,156.7,19.8,25.0,13.0,27.0,27.4,174.7,297.0,32.0,57.6,18.4,38.7,12.8,131.0,24.5,32.0,27.0,99.6,18.0,28.5,14.4,29.7,37.2,107.0,29.0,49.3,60.8,15.0,108.0,13.0,10.0,82.0,19.0,29.8,32.0,87.4,17.2,47.0,37.0,12.0,119.0,85.0,48.0,120.0,21.6,44.1,63.6,19.0,12.0,32.0,126.7,72.3,38.0,163.2,30.2,117.0,79.0,135.0,10.0,73.0,84.2,28.0,30.2,24.0,74.6,50.0,57.0,17.0,135.0,56.0,39.0,68.0,43.0,47.0,89.7,24.8,61.4,32.0,13.0,19.0,32.0,98.0,106.0,12.0,20.0,40.5,21.0,28.0,21.2,22.0,123.0,26.0,37.0,30.0,30.0,21.0,10.5,24.1,14.7,32.1,33.1,41.0,82.5,36.0,55.0,234.0,41.0,7.0,40.0,34.0,24.9,79.5,14.0,33.0,24.0,26.5,23.0,22.3,40.9,20.2,27.0,160.0,56.8,32.9,42.0,57.0,32.0,25.0,62.0,35.0,35.0,45.0,38.0,34.0,140.6,16.9,17.0,30.0,41.0,30.6,98.8,24.0,14.0,70.0,34.0,146.0,125.5,9.0,26.0,19.0,26.9,109.0,17.0,37.0,16.0,19.0,9.0,18.0,56.0,59.0,31.0,27.0,111.1,122.8,43.0,20.0,30.0,30.4,17.0,28.3,15.0,163.0,86.0,26.0,18.0,43.6,52.0,86.0,42.0,36.0,18.0,76.0,16.0,24.0,65.0,11.0,99.0,22.0,29.8,75.0,22.0,33.0,21.0,13.0,58.7,196.0,34.0,12.4,18.0,21.0,39.0,25.6,14 ...
